# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#Read csv file
df = pd.read_csv("test_data.csv")

# %%
#List first 5 records
df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %%
sample = df.sample(10428)

# %%
#List first 5 records
df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %%
#Read csv file
df = pd.read_csv("test_data.csv")

# %%
#List first 5 records
df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1        530      20000    2          2         2   21     -1     -1      2
# 2       1225      20000    1          2         2   21      0      0     -1
# 3       1472      20000    1          2         2   21      0      0      2
# 4       2207      20000    2          1         2   21      0      0      0
#
#       X9  ...        X17       X18       X19       X20       X21       X22  \
# 0  PAY_4  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 1      2  ...          0     14410         0        28     22073         0
# 2      0  ...          0      1240      2333         0         0         0
# 3      0  ...          0      5000         0         0         0         0
# 4      0  ...       2055      1400      3500      1567       162      2055
#
# ...

# %%
sample = df.sample(10428)

# %%
sample.to_csv('test_data.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 sample.to_csv('test_data.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...

# %%
#Read csv file
df = pd.read_csv("test_data.csv")

# %%
sample = df.sample(10428)

# %%
df.head()
# Out:
#      ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   530      20000    2          2         2   21     -1     -1      2      2
# 1  1225      20000    1          2         2   21      0      0     -1      0
# 2  1472      20000    1          2         2   21      0      0      2      0
# 3  2207      20000    2          1         2   21      0      0      0      0
# 4  2213      10000    1          2         2   21      0      0      0      0
#
#    ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...          0     14410         0        28     22073         0         0
# 1  ...          0      1240      2333         0         0         0         0
# 2  ...          0      5000         0         0         0         0         0
# 3  ...       2055      1400      3500      1567       162      2055         0
# 4  ...       9000      1217      1000       200       700       200         0
#
# ...

# %%
sample[['AGE', 'Final Calculation']].to_csv('rand-sample-raw.csv')

# %%
#Read csv file
df = pd.read_csv("test_data.csv")

# %%
df.head()
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  18246     440000    1          1         1   79      0      0      0
# 1    247     250000    2          2         1   75      0     -1     -1
# 2  25137     180000    1          1         1   75      1     -2     -2
# 3  25142     210000    1          2         1   75      0      0      0
# 4  29176     160000    2          3         1   74      0      0      0
#
#    PAY_4  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...     447543     15715     16519     16513     15800     16531
# 1     -1  ...        794      1631      1536      1010      5572       794
# 2     -2  ...          0         0         0         0         0         0
# 3      0  ...     210006      9700      8810      9000      7300      7500
# 4     -1  ...      19789      3783      2268     16905         0     19789
#
#    PAY_AMT6  default payment next month         Raw  Final Calculation
# ...

# %%
sample = df.sample(4572)

# %%
sample[['AGE', 'Final Calculation']].to_csv('rand-sample-raw.csv')

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#Read csv file
priv_data = pd.read_csv("priviledged_raw_data.csv")

# %%
priv_data.head()
# Out:
#      ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   530      20000    2          2         2   21     -1     -1      2      2
# 1  1225      20000    1          2         2   21      0      0     -1      0
# 2  1472      20000    1          2         2   21      0      0      2      0
# 3  2207      20000    2          1         2   21      0      0      0      0
# 4  2213      10000    1          2         2   21      0      0      0      0
#
#    ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...     14410         0        28     22073         0         0
# 1  ...      1240      2333         0         0         0         0
# 2  ...      5000         0         0         0         0         0
# 3  ...      1400      3500      1567       162      2055         0
# 4  ...      1217      1000       200       700       200         0
#
#    default payment next month     Raw  Final Calculation  Profit - Status
# ...

# %%
priv_sample = priv_data.sample(10428)

# %%
priv_sample[['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','default payment next month','Final Calculation','Profit - Status']].to_csv('rand-sample-raw.csv')

# %%
#Read csv file
unpriv_data = pd.read_csv("unpriviledged_raw_data.csv")

# %%
unpriv_data.head()
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   24     450000    2          1         1   40     -2     -2     -2     -2
# 1   37     280000    1          2         1   40      0      0      0      0
# 2  122     450000    1          1         1   40      1     -2     -2     -2
# 3  221     360000    2          1         1   40      2      2      2      0
# 4  245      30000    2          1         2   40     -1     -1      2      2
#
#    ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...     19428      1473       560         0         0      1128
# 1  ...      8026      8060      6300      6400      6400      6737
# 2  ...         0         0         0         0         0         0
# 3  ...     12000         0      5900      5000      4500      4700
# 4  ...       355       120         0         0        60        60
#
#    default payment next month         Raw  Final Calculation  Profit - Status
# ...

# %%
unpriv_sample = unpriv_data.sample(4572)

# %%
unpriv_sample[['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','default payment next month','Final Calculation','Profit - Status']].to_csv('rand-sample-raw.csv')

# %%
import numpy as np
from aif360.datasets import GermanDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 from aif360.datasets import GermanDataset
#
# ModuleNotFoundError: No module named 'aif360'

# %%
import aif360 as a360
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import aif360 as a360
#
# ModuleNotFoundError: No module named 'aif360'
